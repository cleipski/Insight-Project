# %% [markdown]
# # Communicating with the Flickr API
#
# Make calls to the Flickr API and retrieve images for a certain geographical location

# %%
import requests
import os
import json
import pandas as pd
import glob
import numpy as np
import datetime
from time import gmtime, strftime

# %%
# Grab private data
if __name__ == "__main__":
    FLICKR_API_KEY =  os.environ['FLICKR_API_KEY']
    #print(os.environ["FLICKR_API_KEY"])

# %%
# Check if directory exists, if not, create
def checkdir(path):
    try: 
        os.makedirs(path)
    except OSError:
        if not os.path.isdir(path):
            raise

# %%
def flickr_photo_search(api_key,api_long='',api_lat='',radius='',response_format='json',
                       per_page='100',page='1',bbox='',extras='',min_upload_date='',
                       max_upload_date=''):
    # set some general API keys
    api_method = 'flickr.photos.search'
    # process function input
    if len(api_long) > 0: 
        api_long = '&lon='+api_long 
    if len(api_lat) > 0: 
        api_lat = '&lat='+api_lat
    if len(radius) > 0:
        radius = '&radius='+radius
    if len(bbox) > 0:
        bbox = '&bbox='+bbox
    if len(extras) > 0:
        extras = '&extras='+extras
    if len(min_upload_date) > 0:
        min_upload_date = '&min_upload_date='+min_upload_date
    if len(max_upload_date) > 0:
        max_upload_date = '&max_upload_date='+max_upload_date
    # build the call string
    api_call = ('https://api.flickr.com/services/rest/?method=' + 
                api_method + 
                '&api_key='+ api_key +
                min_upload_date+
                max_upload_date+
                api_lat+ 
                api_long+ 
                radius+
                bbox+
                extras+
                '&per_page='+per_page+
                '&page='+page+
                '&format='+response_format+ 
                '&nojsoncallback=1')    
    return api_call

# %%
def flickr_photo_details(api_key,photo_id,response_format='json'):
    api_method = 'flickr.photos.getInfo'
    photo_id = '&photo_id='+photo_id
    api_call = ('https://api.flickr.com/services/rest/?method=' + 
                api_method + 
                '&api_key='+ api_key +
                photo_id+
                '&format='+response_format+ 
                '&nojsoncallback=1')
    return api_call

# %%
def get_bbox(county):
    # get data
    try:
        counties = long_lat['county'].tolist()
    except:
        long_lat = pd.read_csv(os.path.join('..','data',
                                            'county_boundaries',
                                            'min_max.txt'))
        counties = long_lat['county'].tolist()
    # get min/max values
    lat_min = long_lat['lat_min'][long_lat['county'] == county].tolist()[0]
    lat_max = long_lat['lat_max'][long_lat['county'] == county].tolist()[0]
    lng_min = long_lat['long_min'][long_lat['county'] == county].tolist()[0]
    lng_max = long_lat['long_max'][long_lat['county'] == county].tolist()[0]
    # build bbox string
    bbox = '{:f},{:f},{:f},{:f}'.format(lng_min,lat_min,lng_max,lat_max)
    return bbox

# %%
def create_timestring(min_time,max_time):
    """
    From datetime objects creates a timestring for Flickr API.
    """
    fmt = "%Y-%m-%d+%H:%M:%S"
    min_upload_date = min_time.strftime(fmt)
    max_upload_date = max_time.strftime(fmt)
    return min_upload_date, max_upload_date

# %%
def get_timestamp(time):
    """
    Converts a datetime object to UNIX timestamp.
    """
    _EPOCH = datetime.datetime(1970, 1, 1)
    timestamp = (time - _EPOCH).total_seconds()
    return timestamp

# %%
def find_timestep(latest_date,time_step,limit=3999,**kwargs):
    nimg_in_response = limit + 1
    # half time_step
    while nimg_in_response > limit:
        time_step = time_step / 2. # days
        time_min = latest_date - datetime.timedelta(days=time_step)
        time_max = latest_date
        min_upload_date, max_upload_date = create_timestring(time_min,time_max)
        # make first API call
        api_call = flickr_photo_search(api_key=api_key,
                                       bbox=bbox,
                                       min_upload_date=min_upload_date,
                                       max_upload_date=max_upload_date,
                                       per_page=per_page,extras=api_extras)
        response = requests.get(api_call)
        nimg_in_response = float(response.json()['photos']['total'])
    return time_step, response

# %%
# I start looking for images from this day on, going backwards in time 
latest_date_str = '9/6/2016 00:00' 
fmt = '%m/%d/%Y %H:%M'
latest_date = datetime.datetime.strptime(latest_date_str, fmt)
print latest_date
# Out:
# 2016-09-06 00:00:00

# %%
# General API settings
# Get API key from API explorer, will require a new key after some time 
# (reload explorer page, make a call, copy API key from call string at bottom
# of the page)
api_key = '89a4669c0553d3d254b50803bff8f692'
# Maxing out the return per page reduces the amount of additional call for subsequent pages
per_page = '500'
# Grab extra information
api_extras='geo,tags,date_upload,date_taken,url_m,description'

# %%
# Get search box
bbox = get_bbox('Alameda')

# %%
tmp_date_str = '9/6/1968 00:00' 
fmt = '%m/%d/%Y %H:%M'
tmp_date = datetime.datetime.strptime(tmp_date_str, fmt)

_EPOCH = datetime.datetime(1970, 1, 1)
timestamp = (tmp_date - _EPOCH).total_seconds()
print timestamp
# Out:
# -41644800.0

# %%
time_min = latest_date - datetime.timedelta(days=time_step)
time_max = latest_date
timestamp_min = int(get_timestamp(time_min))
timestamp_max = int(get_timestamp(time_max))
dest_file = 'data_{:d}_{:d}_{:04d}.json'.format(timestamp_min,timestamp_max,1)
print dest_file
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-30ca82d0b1f4> in <module>()
# ----> 1 time_min = latest_date - datetime.timedelta(days=time_step)
#       2 time_max = latest_date
#       3 timestamp_min = int(get_timestamp(time_min))
#       4 timestamp_max = int(get_timestamp(time_max))
#       5 dest_file = 'data_{:d}_{:d}_{:04d}.json'.format(timestamp_min,timestamp_max,1)
#
# NameError: name 'time_step' is not defined

# %%
base_dir = os.path.join('..','data','photo_search')
counties = ['Alameda']
counties = ['Contra Costa','San Francisco','Santa Cruz','Sonoma']
counties = ['Contra Costa']

api_key = '51a5b7e0a4e06336707685506ed2f048'

time_step_initial = 45

for county in counties:
    latest_date_str = '9/6/2016 00:00'
#     if county == 'Contra Costa':
#         latest_date_str = '5/20/2009 08:54'
#         latest_date_str = '10/29/1975 11:54'
#     if county == 'San Francisco':
#         latest_date_str = '10/26/2009 09:33'
    fmt = '%m/%d/%Y %H:%M'
    latest_date = datetime.datetime.strptime(latest_date_str, fmt)
    out_query_info = open(os.path.join(base_dir,county+'_query_output.txt'),"w")
    print '+++++++++++++++++++++++++++++'
    print 'County:\n', county
    out_query_info.write('+++++++++++++++++++++++++++++\n')
    out_query_info.write('County: {}\n'.format(county))
    # check folder
    checkdir(os.path.join(base_dir,county))
    # get bbox string
    bbox = get_bbox(county)
    print '\t Bounding box:', bbox    
    out_query_info.write('\t Bounding box: {}\n'.format(bbox))
    latest_date_timestamp = get_timestamp(latest_date)
    while latest_date_timestamp > 0:
        # set time_step
        time_step = time_step_initial # days
        time_min = latest_date - datetime.timedelta(days=time_step)
        time_max = latest_date
        min_upload_date, max_upload_date = create_timestring(time_min,time_max)
        # make an initial call
        api_call = flickr_photo_search(api_key=api_key,
                                       bbox=bbox,
                                       min_upload_date=min_upload_date,
                                       max_upload_date=max_upload_date,
                                       per_page=per_page,
                                       extras=api_extras)
        response = requests.get(api_call)
        nimg_in_response = float(response.json()['photos']['total'])
        print '\t Initial number of images in response (timestep):', nimg_in_response, '(',time_step_initial,')'
        out_query_info.write('\t Initial number of images in response (timestep): {} ( {} )\n'
                                 .format(nimg_in_response,time_step))

        if nimg_in_response > 3999:
            time_step, response = find_timestep(latest_date,time_step,limit=3999,
                                                api_key=api_key,bbox=bbox,
                                                per_page=per_page,extras=api_extras)
            nimg_in_response = float(response.json()['photos']['total'])
            print '\t Final number of images in response (timestep):', nimg_in_response, '(',time_step,')'
            out_query_info.write('\t Final number of images in response (timestep): {} ( {} )\n'
                                 .format(nimg_in_response,time_step))
        # Use the timestep to make the full call
        time_min = latest_date - datetime.timedelta(days=time_step)
        time_max = latest_date
        min_upload_date, max_upload_date = create_timestring(time_min,time_max)
        print '\t Time window (min/max):', time_min, time_max
        out_query_info.write('\t Time window (min/max): {} / {}\n'.format(time_min,time_max))
        # extract successful API call
        max_page = response.json()['photos']['pages']
        print '\t Max. page number:', max_page
        out_query_info.write('\t Max. page number: {}\n'.format(max_page))
        # save first reponse to disk
        dest_dir = os.path.join('..','data','photo_search',county)
        timestamp_min = int(get_timestamp(time_min))
        timestamp_max = int(get_timestamp(time_max))
        dest_file = 'data_{}_{:d}_{:d}_{:04d}.json'.format(
            county,timestamp_min,timestamp_max,1)
        print '\t First file on disk:', dest_file
        out_query_info.write('\t First file on disk: {}\n'.format(dest_file))
        with open(os.path.join(dest_dir,dest_file), 'w') as outfile:
            json.dump(response.json(), outfile)
        # loop through remaining pages
        for page in range(max_page):
            page += 1
            print '\t ', page, '/', max_page
            out_query_info.write('\t {} / {}\n'.format(page,max_page))
            if page > 1:
                api_call = flickr_photo_search(api_key=api_key,
                                               bbox=bbox,
                                               min_upload_date=min_upload_date,
                                               max_upload_date=max_upload_date,
                                               per_page=per_page,
                                               extras=api_extras,
                                               page=str(page))
                response = requests.get(api_call)
                dest_file = 'data_{}_{:d}_{:d}_{:04d}.json'.format(
                    county,timestamp_min,timestamp_max,page)
                print '\t Name of file on disk:', dest_file
                out_query_info.write('\t Name of file on disk: {}\n'.format(dest_file))
                with open(os.path.join(dest_dir,dest_file), 'w') as outfile:
                    json.dump(response.json(), outfile)
        # set current max time as new latest_date
        print '\t ------------------------------------------'
        out_query_info.write('\t ------------------------------------------\n')
        latest_date = time_min 
        latest_date_timestamp = get_timestamp(latest_date)
    out_query_info.close()
# Out:
# +++++++++++++++++++++++++++++
# County:
# Contra Costa
# 	 Bounding box: -122.441580,37.718890,-121.536200,38.097710
# 	 Initial number of images in response (timestep): 14679.0 ( 45 )
# 	 Final number of images in response (timestep): 3343.0 ( 11.25 )
# 	 Time window (min/max): 2016-08-25 18:00:00 2016-09-06 00:00:00
# 	 Max. page number: 7
# 	 First file on disk: data_Contra Costa_1472148000_1473120000_0001.json
# 	  1 / 7
# 	  2 / 7
# 	 Name of file on disk: data_Contra Costa_1472148000_1473120000_0002.json
# 	  3 / 7
# 	 Name of file on disk: data_Contra Costa_1472148000_1473120000_0003.json
# 	  4 / 7
# 	 Name of file on disk: data_Contra Costa_1472148000_1473120000_0004.json
# 	  5 / 7
# 	 Name of file on disk: data_Contra Costa_1472148000_1473120000_0005.json
# 	  6 / 7
# 	 Name of file on disk: data_Contra Costa_1472148000_1473120000_0006.json
# 	  7 / 7
# 	 Name of file on disk: data_Contra Costa_1472148000_1473120000_0007.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 14597.0 ( 45 )
# 	 Final number of images in response (timestep): 2125.0 ( 5.625 )
# 	 Time window (min/max): 2016-08-20 03:00:00 2016-08-25 18:00:00
# 	 Max. page number: 5
# 	 First file on disk: data_Contra Costa_1471662000_1472148000_0001.json
# 	  1 / 5
# 	  2 / 5
# 	 Name of file on disk: data_Contra Costa_1471662000_1472148000_0002.json
# 	  3 / 5
# 	 Name of file on disk: data_Contra Costa_1471662000_1472148000_0003.json
# 	  4 / 5
# 	 Name of file on disk: data_Contra Costa_1471662000_1472148000_0004.json
# 	  5 / 5
# 	 Name of file on disk: data_Contra Costa_1471662000_1472148000_0005.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 14495.0 ( 45 )
# 	 Final number of images in response (timestep): 3662.0 ( 11.25 )
# 	 Time window (min/max): 2016-08-08 21:00:00 2016-08-20 03:00:00
# 	 Max. page number: 8
# 	 First file on disk: data_Contra Costa_1470690000_1471662000_0001.json
# 	  1 / 8
# 	  2 / 8
# 	 Name of file on disk: data_Contra Costa_1470690000_1471662000_0002.json
# 	  3 / 8
# 	 Name of file on disk: data_Contra Costa_1470690000_1471662000_0003.json
# 	  4 / 8
# 	 Name of file on disk: data_Contra Costa_1470690000_1471662000_0004.json
# 	  5 / 8
# 	 Name of file on disk: data_Contra Costa_1470690000_1471662000_0005.json
# 	  6 / 8
# 	 Name of file on disk: data_Contra Costa_1470690000_1471662000_0006.json
# 	  7 / 8
# 	 Name of file on disk: data_Contra Costa_1470690000_1471662000_0007.json
# 	  8 / 8
# 	 Name of file on disk: data_Contra Costa_1470690000_1471662000_0008.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 15413.0 ( 45 )
# 	 Final number of images in response (timestep): 3819.0 ( 11.25 )
# 	 Time window (min/max): 2016-07-28 15:00:00 2016-08-08 21:00:00
# 	 Max. page number: 8
# 	 First file on disk: data_Contra Costa_1469718000_1470690000_0001.json
# 	  1 / 8
# 	  2 / 8
# 	 Name of file on disk: data_Contra Costa_1469718000_1470690000_0002.json
# 	  3 / 8
# 	 Name of file on disk: data_Contra Costa_1469718000_1470690000_0003.json
# 	  4 / 8
# 	 Name of file on disk: data_Contra Costa_1469718000_1470690000_0004.json
# 	  5 / 8
# 	 Name of file on disk: data_Contra Costa_1469718000_1470690000_0005.json
# 	  6 / 8
# 	 Name of file on disk: data_Contra Costa_1469718000_1470690000_0006.json
# 	  7 / 8
# 	 Name of file on disk: data_Contra Costa_1469718000_1470690000_0007.json
# 	  8 / 8
# 	 Name of file on disk: data_Contra Costa_1469718000_1470690000_0008.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 15466.0 ( 45 )
# 	 Final number of images in response (timestep): 3167.0 ( 11.25 )
# 	 Time window (min/max): 2016-07-17 09:00:00 2016-07-28 15:00:00
# 	 Max. page number: 7
# 	 First file on disk: data_Contra Costa_1468746000_1469718000_0001.json
# 	  1 / 7
# 	  2 / 7
# 	 Name of file on disk: data_Contra Costa_1468746000_1469718000_0002.json
# 	  3 / 7
# 	 Name of file on disk: data_Contra Costa_1468746000_1469718000_0003.json
# 	  4 / 7
# 	 Name of file on disk: data_Contra Costa_1468746000_1469718000_0004.json
# 	  5 / 7
# 	 Name of file on disk: data_Contra Costa_1468746000_1469718000_0005.json
# 	  6 / 7
# 	 Name of file on disk: data_Contra Costa_1468746000_1469718000_0006.json
# 	  7 / 7
# 	 Name of file on disk: data_Contra Costa_1468746000_1469718000_0007.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 16827.0 ( 45 )
# 	 Final number of images in response (timestep): 3534.0 ( 11.25 )
# 	 Time window (min/max): 2016-07-06 03:00:00 2016-07-17 09:00:00
# 	 Max. page number: 8
# 	 First file on disk: data_Contra Costa_1467774000_1468746000_0001.json
# 	  1 / 8
# 	  2 / 8
# 	 Name of file on disk: data_Contra Costa_1467774000_1468746000_0002.json
# 	  3 / 8
# 	 Name of file on disk: data_Contra Costa_1467774000_1468746000_0003.json
# 	  4 / 8
# 	 Name of file on disk: data_Contra Costa_1467774000_1468746000_0004.json
# 	  5 / 8
# 	 Name of file on disk: data_Contra Costa_1467774000_1468746000_0005.json
# 	  6 / 8
# 	 Name of file on disk: data_Contra Costa_1467774000_1468746000_0006.json
# 	  7 / 8
# 	 Name of file on disk: data_Contra Costa_1467774000_1468746000_0007.json
# 	  8 / 8
# 	 Name of file on disk: data_Contra Costa_1467774000_1468746000_0008.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 17384.0 ( 45 )
# 	 Final number of images in response (timestep): 1887.0 ( 5.625 )
# 	 Time window (min/max): 2016-06-30 12:00:00 2016-07-06 03:00:00
# 	 Max. page number: 4
# 	 First file on disk: data_Contra Costa_1467288000_1467774000_0001.json
# 	  1 / 4
# 	  2 / 4
# 	 Name of file on disk: data_Contra Costa_1467288000_1467774000_0002.json
# 	  3 / 4
# 	 Name of file on disk: data_Contra Costa_1467288000_1467774000_0003.json
# 	  4 / 4
# 	 Name of file on disk: data_Contra Costa_1467288000_1467774000_0004.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 17399.0 ( 45 )
# 	 Final number of images in response (timestep): 2874.0 ( 5.625 )
# 	 Time window (min/max): 2016-06-24 21:00:00 2016-06-30 12:00:00
# 	 Max. page number: 6
# 	 First file on disk: data_Contra Costa_1466802000_1467288000_0001.json
# 	  1 / 6
# 	  2 / 6
# 	 Name of file on disk: data_Contra Costa_1466802000_1467288000_0002.json
# 	  3 / 6
# 	 Name of file on disk: data_Contra Costa_1466802000_1467288000_0003.json
# 	  4 / 6
# 	 Name of file on disk: data_Contra Costa_1466802000_1467288000_0004.json
# 	  5 / 6
# 	 Name of file on disk: data_Contra Costa_1466802000_1467288000_0005.json
# 	  6 / 6
# 	 Name of file on disk: data_Contra Costa_1466802000_1467288000_0006.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 16091.0 ( 45 )
# 	 Final number of images in response (timestep): 1929.0 ( 5.625 )
# 	 Time window (min/max): 2016-06-19 06:00:00 2016-06-24 21:00:00
# 	 Max. page number: 4
# 	 First file on disk: data_Contra Costa_1466316000_1466802000_0001.json
# 	  1 / 4
# 	  2 / 4
# 	 Name of file on disk: data_Contra Costa_1466316000_1466802000_0002.json
# 	  3 / 4
# 	 Name of file on disk: data_Contra Costa_1466316000_1466802000_0003.json
# 	  4 / 4
# 	 Name of file on disk: data_Contra Costa_1466316000_1466802000_0004.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 15683.0 ( 45 )
# 	 Final number of images in response (timestep): 2150.0 ( 5.625 )
# 	 Time window (min/max): 2016-06-13 15:00:00 2016-06-19 06:00:00
# 	 Max. page number: 5
# 	 First file on disk: data_Contra Costa_1465830000_1466316000_0001.json
# 	  1 / 5
# 	  2 / 5
# 	 Name of file on disk: data_Contra Costa_1465830000_1466316000_0002.json
# 	  3 / 5
# 	 Name of file on disk: data_Contra Costa_1465830000_1466316000_0003.json
# 	  4 / 5
# 	 Name of file on disk: data_Contra Costa_1465830000_1466316000_0004.json
# 	  5 / 5
# 	 Name of file on disk: data_Contra Costa_1465830000_1466316000_0005.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 13365.0 ( 45 )
# 	 Final number of images in response (timestep): 2375.0 ( 5.625 )
# 	 Time window (min/max): 2016-06-08 00:00:00 2016-06-13 15:00:00
# 	 Max. page number: 5
# 	 First file on disk: data_Contra Costa_1465344000_1465830000_0001.json
# 	  1 / 5
# 	  2 / 5
# 	 Name of file on disk: data_Contra Costa_1465344000_1465830000_0002.json
# 	  3 / 5
# 	 Name of file on disk: data_Contra Costa_1465344000_1465830000_0003.json
# 	  4 / 5
# 	 Name of file on disk: data_Contra Costa_1465344000_1465830000_0004.json
# 	  5 / 5
# 	 Name of file on disk: data_Contra Costa_1465344000_1465830000_0005.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 15316.0 ( 45 )
# 	 Final number of images in response (timestep): 3690.0 ( 11.25 )
# 	 Time window (min/max): 2016-05-27 18:00:00 2016-06-08 00:00:00
# 	 Max. page number: 8
# 	 First file on disk: data_Contra Costa_1464372000_1465344000_0001.json
# 	  1 / 8
# 	  2 / 8
# 	 Name of file on disk: data_Contra Costa_1464372000_1465344000_0002.json
# 	  3 / 8
# 	 Name of file on disk: data_Contra Costa_1464372000_1465344000_0003.json
# 	  4 / 8
# 	 Name of file on disk: data_Contra Costa_1464372000_1465344000_0004.json
# 	  5 / 8
# 	 Name of file on disk: data_Contra Costa_1464372000_1465344000_0005.json
# 	  6 / 8
# 	 Name of file on disk: data_Contra Costa_1464372000_1465344000_0006.json
# 	  7 / 8
# 	 Name of file on disk: data_Contra Costa_1464372000_1465344000_0007.json
# 	  8 / 8
# 	 Name of file on disk: data_Contra Costa_1464372000_1465344000_0008.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 16019.0 ( 45 )
# 	 Final number of images in response (timestep): 3807.0 ( 11.25 )
# 	 Time window (min/max): 2016-05-16 12:00:00 2016-05-27 18:00:00
# 	 Max. page number: 8
# 	 First file on disk: data_Contra Costa_1463400000_1464372000_0001.json
# 	  1 / 8
# 	  2 / 8
# 	 Name of file on disk: data_Contra Costa_1463400000_1464372000_0002.json
# 	  3 / 8
# 	 Name of file on disk: data_Contra Costa_1463400000_1464372000_0003.json
# 	  4 / 8
# 	 Name of file on disk: data_Contra Costa_1463400000_1464372000_0004.json
# 	  5 / 8
# 	 Name of file on disk: data_Contra Costa_1463400000_1464372000_0005.json
# 	  6 / 8
# 	 Name of file on disk: data_Contra Costa_1463400000_1464372000_0006.json
# 	  7 / 8
# 	 Name of file on disk: data_Contra Costa_1463400000_1464372000_0007.json
# 	  8 / 8
# 	 Name of file on disk: data_Contra Costa_1463400000_1464372000_0008.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 16362.0 ( 45 )
# 	 Final number of images in response (timestep): 3736.0 ( 11.25 )
# 	 Time window (min/max): 2016-05-05 06:00:00 2016-05-16 12:00:00
# 	 Max. page number: 8
# 	 First file on disk: data_Contra Costa_1462428000_1463400000_0001.json
# 	  1 / 8
# 	  2 / 8
# 	 Name of file on disk: data_Contra Costa_1462428000_1463400000_0002.json
# 	  3 / 8
# 	 Name of file on disk: data_Contra Costa_1462428000_1463400000_0003.json
# 	  4 / 8
# 	 Name of file on disk: data_Contra Costa_1462428000_1463400000_0004.json
# 	  5 / 8
# 	 Name of file on disk: data_Contra Costa_1462428000_1463400000_0005.json
# 	  6 / 8
# 	 Name of file on disk: data_Contra Costa_1462428000_1463400000_0006.json
# 	  7 / 8
# 	 Name of file on disk: data_Contra Costa_1462428000_1463400000_0007.json
# 	  8 / 8
# 	 Name of file on disk: data_Contra Costa_1462428000_1463400000_0008.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 15205.0 ( 45 )
# 	 Final number of images in response (timestep): 3809.0 ( 11.25 )
# 	 Time window (min/max): 2016-04-24 00:00:00 2016-05-05 06:00:00
# 	 Max. page number: 8
# 	 First file on disk: data_Contra Costa_1461456000_1462428000_0001.json
# 	  1 / 8
# 	  2 / 8
# 	 Name of file on disk: data_Contra Costa_1461456000_1462428000_0002.json
# 	  3 / 8
# 	 Name of file on disk: data_Contra Costa_1461456000_1462428000_0003.json
# 	  4 / 8
# 	 Name of file on disk: data_Contra Costa_1461456000_1462428000_0004.json
# 	  5 / 8
# 	 Name of file on disk: data_Contra Costa_1461456000_1462428000_0005.json
# 	  6 / 8
# 	 Name of file on disk: data_Contra Costa_1461456000_1462428000_0006.json
# 	  7 / 8
# 	 Name of file on disk: data_Contra Costa_1461456000_1462428000_0007.json
# 	  8 / 8
# 	 Name of file on disk: data_Contra Costa_1461456000_1462428000_0008.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 15237.0 ( 45 )
# 	 Final number of images in response (timestep): 1960.0 ( 5.625 )
# 	 Time window (min/max): 2016-04-18 09:00:00 2016-04-24 00:00:00
# 	 Max. page number: 4
# 	 First file on disk: data_Contra Costa_1460970000_1461456000_0001.json
# 	  1 / 4
# 	  2 / 4
# 	 Name of file on disk: data_Contra Costa_1460970000_1461456000_0002.json
# 	  3 / 4
# 	 Name of file on disk: data_Contra Costa_1460970000_1461456000_0003.json
# 	  4 / 4
# 	 Name of file on disk: data_Contra Costa_1460970000_1461456000_0004.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 13678.0 ( 45 )
# 	 Final number of images in response (timestep): 3775.0 ( 11.25 )
# 	 Time window (min/max): 2016-04-07 03:00:00 2016-04-18 09:00:00
# 	 Max. page number: 8
# 	 First file on disk: data_Contra Costa_1459998000_1460970000_0001.json
# 	  1 / 8
# 	  2 / 8
# 	 Name of file on disk: data_Contra Costa_1459998000_1460970000_0002.json
# 	  3 / 8
# 	 Name of file on disk: data_Contra Costa_1459998000_1460970000_0003.json
# 	  4 / 8
# 	 Name of file on disk: data_Contra Costa_1459998000_1460970000_0004.json
# 	  5 / 8
# 	 Name of file on disk: data_Contra Costa_1459998000_1460970000_0005.json
# 	  6 / 8
# 	 Name of file on disk: data_Contra Costa_1459998000_1460970000_0006.json
# 	  7 / 8
# 	 Name of file on disk: data_Contra Costa_1459998000_1460970000_0007.json
# 	  8 / 8
# 	 Name of file on disk: data_Contra Costa_1459998000_1460970000_0008.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 15718.0 ( 45 )
# 	 Final number of images in response (timestep): 3780.0 ( 11.25 )
# 	 Time window (min/max): 2016-03-26 21:00:00 2016-04-07 03:00:00
# 	 Max. page number: 8
# 	 First file on disk: data_Contra Costa_1459026000_1459998000_0001.json
# 	  1 / 8
# 	  2 / 8
# 	 Name of file on disk: data_Contra Costa_1459026000_1459998000_0002.json
# 	  3 / 8
# 	 Name of file on disk: data_Contra Costa_1459026000_1459998000_0003.json
# 	  4 / 8
# 	 Name of file on disk: data_Contra Costa_1459026000_1459998000_0004.json
# 	  5 / 8
# 	 Name of file on disk: data_Contra Costa_1459026000_1459998000_0005.json
# 	  6 / 8
# 	 Name of file on disk: data_Contra Costa_1459026000_1459998000_0006.json
# 	  7 / 8
# 	 Name of file on disk: data_Contra Costa_1459026000_1459998000_0007.json
# 	  8 / 8
# 	 Name of file on disk: data_Contra Costa_1459026000_1459998000_0008.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 15081.0 ( 45 )
# 	 Final number of images in response (timestep): 3190.0 ( 11.25 )
# 	 Time window (min/max): 2016-03-15 15:00:00 2016-03-26 21:00:00
# 	 Max. page number: 7
# 	 First file on disk: data_Contra Costa_1458054000_1459026000_0001.json
# 	  1 / 7
# 	  2 / 7
# 	 Name of file on disk: data_Contra Costa_1458054000_1459026000_0002.json
# 	  3 / 7
# 	 Name of file on disk: data_Contra Costa_1458054000_1459026000_0003.json
# 	  4 / 7
# 	 Name of file on disk: data_Contra Costa_1458054000_1459026000_0004.json
# 	  5 / 7
# 	 Name of file on disk: data_Contra Costa_1458054000_1459026000_0005.json
# 	  6 / 7
# 	 Name of file on disk: data_Contra Costa_1458054000_1459026000_0006.json
# 	  7 / 7
# 	 Name of file on disk: data_Contra Costa_1458054000_1459026000_0007.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 17320.0 ( 45 )
# 	 Final number of images in response (timestep): 1729.0 ( 5.625 )
# 	 Time window (min/max): 2016-03-10 00:00:00 2016-03-15 15:00:00
# 	 Max. page number: 4
# 	 First file on disk: data_Contra Costa_1457568000_1458054000_0001.json
# 	  1 / 4
# 	  2 / 4
# 	 Name of file on disk: data_Contra Costa_1457568000_1458054000_0002.json
# 	  3 / 4
# 	 Name of file on disk: data_Contra Costa_1457568000_1458054000_0003.json
# 	  4 / 4
# 	 Name of file on disk: data_Contra Costa_1457568000_1458054000_0004.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 18392.0 ( 45 )
# 	 Final number of images in response (timestep): 2701.0 ( 5.625 )
# 	 Time window (min/max): 2016-03-04 09:00:00 2016-03-10 00:00:00
# 	 Max. page number: 6
# 	 First file on disk: data_Contra Costa_1457082000_1457568000_0001.json
# 	  1 / 6
# 	  2 / 6
# 	 Name of file on disk: data_Contra Costa_1457082000_1457568000_0002.json
# 	  3 / 6
# 	 Name of file on disk: data_Contra Costa_1457082000_1457568000_0003.json
# 	  4 / 6
# 	 Name of file on disk: data_Contra Costa_1457082000_1457568000_0004.json
# 	  5 / 6
# 	 Name of file on disk: data_Contra Costa_1457082000_1457568000_0005.json
# 	  6 / 6
# 	 Name of file on disk: data_Contra Costa_1457082000_1457568000_0006.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 17018.0 ( 45 )
# 	 Final number of images in response (timestep): 2082.0 ( 5.625 )
# 	 Time window (min/max): 2016-02-27 18:00:00 2016-03-04 09:00:00
# 	 Max. page number: 5
# 	 First file on disk: data_Contra Costa_1456596000_1457082000_0001.json
# 	  1 / 5
# 	  2 / 5
# 	 Name of file on disk: data_Contra Costa_1456596000_1457082000_0002.json
# 	  3 / 5
# 	 Name of file on disk: data_Contra Costa_1456596000_1457082000_0003.json
# 	  4 / 5
# 	 Name of file on disk: data_Contra Costa_1456596000_1457082000_0004.json
# 	  5 / 5
# 	 Name of file on disk: data_Contra Costa_1456596000_1457082000_0005.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 17134.0 ( 45 )
# 	 Final number of images in response (timestep): 2196.0 ( 5.625 )
# 	 Time window (min/max): 2016-02-22 03:00:00 2016-02-27 18:00:00
# 	 Max. page number: 5
# 	 First file on disk: data_Contra Costa_1456110000_1456596000_0001.json
# 	  1 / 5
# 	  2 / 5
# 	 Name of file on disk: data_Contra Costa_1456110000_1456596000_0002.json
# 	  3 / 5
# 	 Name of file on disk: data_Contra Costa_1456110000_1456596000_0003.json
# 	  4 / 5
# 	 Name of file on disk: data_Contra Costa_1456110000_1456596000_0004.json
# 	  5 / 5
# 	 Name of file on disk: data_Contra Costa_1456110000_1456596000_0005.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 16609.0 ( 45 )
# 	 Final number of images in response (timestep): 3742.0 ( 11.25 )
# 	 Time window (min/max): 2016-02-10 21:00:00 2016-02-22 03:00:00
# 	 Max. page number: 8
# 	 First file on disk: data_Contra Costa_1455138000_1456110000_0001.json
# 	  1 / 8
# 	  2 / 8
# 	 Name of file on disk: data_Contra Costa_1455138000_1456110000_0002.json
# 	  3 / 8
# 	 Name of file on disk: data_Contra Costa_1455138000_1456110000_0003.json
# 	  4 / 8
# 	 Name of file on disk: data_Contra Costa_1455138000_1456110000_0004.json
# 	  5 / 8
# 	 Name of file on disk: data_Contra Costa_1455138000_1456110000_0005.json
# 	  6 / 8
# 	 Name of file on disk: data_Contra Costa_1455138000_1456110000_0006.json
# 	  7 / 8
# 	 Name of file on disk: data_Contra Costa_1455138000_1456110000_0007.json
# 	  8 / 8
# 	 Name of file on disk: data_Contra Costa_1455138000_1456110000_0008.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 15561.0 ( 45 )
# 	 Final number of images in response (timestep): 2362.0 ( 5.625 )
# 	 Time window (min/max): 2016-02-05 06:00:00 2016-02-10 21:00:00
# 	 Max. page number: 5
# 	 First file on disk: data_Contra Costa_1454652000_1455138000_0001.json
# 	  1 / 5
# 	  2 / 5
# 	 Name of file on disk: data_Contra Costa_1454652000_1455138000_0002.json
# 	  3 / 5
# 	 Name of file on disk: data_Contra Costa_1454652000_1455138000_0003.json
# 	  4 / 5
# 	 Name of file on disk: data_Contra Costa_1454652000_1455138000_0004.json
# 	  5 / 5
# 	 Name of file on disk: data_Contra Costa_1454652000_1455138000_0005.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 13665.0 ( 45 )
# 	 Final number of images in response (timestep): 2294.0 ( 5.625 )
# 	 Time window (min/max): 2016-01-30 15:00:00 2016-02-05 06:00:00
# 	 Max. page number: 5
# 	 First file on disk: data_Contra Costa_1454166000_1454652000_0001.json
# 	  1 / 5
# 	  2 / 5
# 	 Name of file on disk: data_Contra Costa_1454166000_1454652000_0002.json
# 	  3 / 5
# 	 Name of file on disk: data_Contra Costa_1454166000_1454652000_0003.json
# 	  4 / 5
# 	 Name of file on disk: data_Contra Costa_1454166000_1454652000_0004.json
# 	  5 / 5
# 	 Name of file on disk: data_Contra Costa_1454166000_1454652000_0005.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 13397.0 ( 45 )
# 	 Final number of images in response (timestep): 2598.0 ( 5.625 )
# 	 Time window (min/max): 2016-01-25 00:00:00 2016-01-30 15:00:00
# 	 Max. page number: 6
# 	 First file on disk: data_Contra Costa_1453680000_1454166000_0001.json
# 	  1 / 6
# 	  2 / 6
# 	 Name of file on disk: data_Contra Costa_1453680000_1454166000_0002.json
# 	  3 / 6
# 	 Name of file on disk: data_Contra Costa_1453680000_1454166000_0003.json
# 	  4 / 6
# 	 Name of file on disk: data_Contra Costa_1453680000_1454166000_0004.json
# 	  5 / 6
# 	 Name of file on disk: data_Contra Costa_1453680000_1454166000_0005.json
# 	  6 / 6
# 	 Name of file on disk: data_Contra Costa_1453680000_1454166000_0006.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 12779.0 ( 45 )
# 	 Final number of images in response (timestep): 3500.0 ( 11.25 )
# 	 Time window (min/max): 2016-01-13 18:00:00 2016-01-25 00:00:00
# 	 Max. page number: 7
# 	 First file on disk: data_Contra Costa_1452708000_1453680000_0001.json
# 	  1 / 7
# 	  2 / 7
# 	 Name of file on disk: data_Contra Costa_1452708000_1453680000_0002.json
# 	  3 / 7
# 	 Name of file on disk: data_Contra Costa_1452708000_1453680000_0003.json
# 	  4 / 7
# 	 Name of file on disk: data_Contra Costa_1452708000_1453680000_0004.json
# 	  5 / 7
# 	 Name of file on disk: data_Contra Costa_1452708000_1453680000_0005.json
# 	  6 / 7
# 	 Name of file on disk: data_Contra Costa_1452708000_1453680000_0006.json
# 	  7 / 7
# 	 Name of file on disk: data_Contra Costa_1452708000_1453680000_0007.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 13121.0 ( 45 )
# 	 Final number of images in response (timestep): 3090.0 ( 11.25 )
# 	 Time window (min/max): 2016-01-02 12:00:00 2016-01-13 18:00:00
# 	 Max. page number: 7
# 	 First file on disk: data_Contra Costa_1451736000_1452708000_0001.json
# 	  1 / 7
# 	  2 / 7
# 	 Name of file on disk: data_Contra Costa_1451736000_1452708000_0002.json
# 	  3 / 7
# 	 Name of file on disk: data_Contra Costa_1451736000_1452708000_0003.json
# 	  4 / 7
# 	 Name of file on disk: data_Contra Costa_1451736000_1452708000_0004.json
# 	  5 / 7
# 	 Name of file on disk: data_Contra Costa_1451736000_1452708000_0005.json
# 	  6 / 7
# 	 Name of file on disk: data_Contra Costa_1451736000_1452708000_0006.json
# 	  7 / 7
# 	 Name of file on disk: data_Contra Costa_1451736000_1452708000_0007.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 16174.0 ( 45 )
# 	 Final number of images in response (timestep): 2865.0 ( 11.25 )
# 	 Time window (min/max): 2015-12-22 06:00:00 2016-01-02 12:00:00
# 	 Max. page number: 6
# 	 First file on disk: data_Contra Costa_1450764000_1451736000_0001.json
# 	  1 / 6
# 	  2 / 6
# 	 Name of file on disk: data_Contra Costa_1450764000_1451736000_0002.json
# 	  3 / 6
# 	 Name of file on disk: data_Contra Costa_1450764000_1451736000_0003.json
# 	  4 / 6
# 	 Name of file on disk: data_Contra Costa_1450764000_1451736000_0004.json
# 	  5 / 6
# 	 Name of file on disk: data_Contra Costa_1450764000_1451736000_0005.json
# 	  6 / 6
# 	 Name of file on disk: data_Contra Costa_1450764000_1451736000_0006.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 16558.0 ( 45 )
# 	 Final number of images in response (timestep): 3539.0 ( 11.25 )
# 	 Time window (min/max): 2015-12-11 00:00:00 2015-12-22 06:00:00
# 	 Max. page number: 8
# 	 First file on disk: data_Contra Costa_1449792000_1450764000_0001.json
# 	  1 / 8
# 	  2 / 8
# 	 Name of file on disk: data_Contra Costa_1449792000_1450764000_0002.json
# 	  3 / 8
# 	 Name of file on disk: data_Contra Costa_1449792000_1450764000_0003.json
# 	  4 / 8
# 	 Name of file on disk: data_Contra Costa_1449792000_1450764000_0004.json
# 	  5 / 8
# 	 Name of file on disk: data_Contra Costa_1449792000_1450764000_0005.json
# 	  6 / 8
# 	 Name of file on disk: data_Contra Costa_1449792000_1450764000_0006.json
# 	  7 / 8
# 	 Name of file on disk: data_Contra Costa_1449792000_1450764000_0007.json
# 	  8 / 8
# 	 Name of file on disk: data_Contra Costa_1449792000_1450764000_0008.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 17751.0 ( 45 )
# 	 Final number of images in response (timestep): 3794.0 ( 11.25 )
# 	 Time window (min/max): 2015-11-29 18:00:00 2015-12-11 00:00:00
# 	 Max. page number: 8
# 	 First file on disk: data_Contra Costa_1448820000_1449792000_0001.json
# 	  1 / 8
# 	  2 / 8
# 	 Name of file on disk: data_Contra Costa_1448820000_1449792000_0002.json
# 	  3 / 8
# 	 Name of file on disk: data_Contra Costa_1448820000_1449792000_0003.json
# 	  4 / 8
# 	 Name of file on disk: data_Contra Costa_1448820000_1449792000_0004.json
# 	  5 / 8
# 	 Name of file on disk: data_Contra Costa_1448820000_1449792000_0005.json
# 	  6 / 8
# 	 Name of file on disk: data_Contra Costa_1448820000_1449792000_0006.json
# 	  7 / 8
# 	 Name of file on disk: data_Contra Costa_1448820000_1449792000_0007.json
# 	  8 / 8
# 	 Name of file on disk: data_Contra Costa_1448820000_1449792000_0008.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 18342.0 ( 45 )
# 	 Final number of images in response (timestep): 3556.0 ( 5.625 )
# 	 Time window (min/max): 2015-11-24 03:00:00 2015-11-29 18:00:00
# 	 Max. page number: 8
# 	 First file on disk: data_Contra Costa_1448334000_1448820000_0001.json
# 	  1 / 8
# 	  2 / 8
# 	 Name of file on disk: data_Contra Costa_1448334000_1448820000_0002.json
# 	  3 / 8
# 	 Name of file on disk: data_Contra Costa_1448334000_1448820000_0003.json
# 	  4 / 8
# 	 Name of file on disk: data_Contra Costa_1448334000_1448820000_0004.json
# 	  5 / 8
# 	 Name of file on disk: data_Contra Costa_1448334000_1448820000_0005.json
# 	  6 / 8
# 	 Name of file on disk: data_Contra Costa_1448334000_1448820000_0006.json
# 	  7 / 8
# 	 Name of file on disk: data_Contra Costa_1448334000_1448820000_0007.json
# 	  8 / 8
# 	 Name of file on disk: data_Contra Costa_1448334000_1448820000_0008.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 19850.0 ( 45 )
# 	 Final number of images in response (timestep): 2458.0 ( 5.625 )
# 	 Time window (min/max): 2015-11-18 12:00:00 2015-11-24 03:00:00
# 	 Max. page number: 5
# 	 First file on disk: data_Contra Costa_1447848000_1448334000_0001.json
# 	  1 / 5
# 	  2 / 5
# 	 Name of file on disk: data_Contra Costa_1447848000_1448334000_0002.json
# 	  3 / 5
# 	 Name of file on disk: data_Contra Costa_1447848000_1448334000_0003.json
# 	  4 / 5
# 	 Name of file on disk: data_Contra Costa_1447848000_1448334000_0004.json
# 	  5 / 5
# 	 Name of file on disk: data_Contra Costa_1447848000_1448334000_0005.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 17252.0 ( 45 )
# 	 Final number of images in response (timestep): 3321.0 ( 11.25 )
# 	 Time window (min/max): 2015-11-07 06:00:00 2015-11-18 12:00:00
# 	 Max. page number: 7
# 	 First file on disk: data_Contra Costa_1446876000_1447848000_0001.json
# 	  1 / 7
# 	  2 / 7
# 	 Name of file on disk: data_Contra Costa_1446876000_1447848000_0002.json
# 	  3 / 7
# 	 Name of file on disk: data_Contra Costa_1446876000_1447848000_0003.json
# 	  4 / 7
# 	 Name of file on disk: data_Contra Costa_1446876000_1447848000_0004.json
# 	  5 / 7
# 	 Name of file on disk: data_Contra Costa_1446876000_1447848000_0005.json
# 	  6 / 7
# 	 Name of file on disk: data_Contra Costa_1446876000_1447848000_0006.json
# 	  7 / 7
# 	 Name of file on disk: data_Contra Costa_1446876000_1447848000_0007.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 16222.0 ( 45 )
# 	 Final number of images in response (timestep): 2302.0 ( 5.625 )
# 	 Time window (min/max): 2015-11-01 15:00:00 2015-11-07 06:00:00
# 	 Max. page number: 5
# 	 First file on disk: data_Contra Costa_1446390000_1446876000_0001.json
# 	  1 / 5
# 	  2 / 5
# 	 Name of file on disk: data_Contra Costa_1446390000_1446876000_0002.json
# 	  3 / 5
# 	 Name of file on disk: data_Contra Costa_1446390000_1446876000_0003.json
# 	  4 / 5
# 	 Name of file on disk: data_Contra Costa_1446390000_1446876000_0004.json
# 	  5 / 5
# 	 Name of file on disk: data_Contra Costa_1446390000_1446876000_0005.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 17353.0 ( 45 )
# 	 Final number of images in response (timestep): 2239.0 ( 5.625 )
# 	 Time window (min/max): 2015-10-27 00:00:00 2015-11-01 15:00:00
# 	 Max. page number: 5
# 	 First file on disk: data_Contra Costa_1445904000_1446390000_0001.json
# 	  1 / 5
# 	  2 / 5
# 	 Name of file on disk: data_Contra Costa_1445904000_1446390000_0002.json
# 	  3 / 5
# 	 Name of file on disk: data_Contra Costa_1445904000_1446390000_0003.json
# 	  4 / 5
# 	 Name of file on disk: data_Contra Costa_1445904000_1446390000_0004.json
# 	  5 / 5
# 	 Name of file on disk: data_Contra Costa_1445904000_1446390000_0005.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 17048.0 ( 45 )
# 	 Final number of images in response (timestep): 1879.0 ( 5.625 )
# 	 Time window (min/max): 2015-10-21 09:00:00 2015-10-27 00:00:00
# 	 Max. page number: 4
# 	 First file on disk: data_Contra Costa_1445418000_1445904000_0001.json
# 	  1 / 4
# 	  2 / 4
# 	 Name of file on disk: data_Contra Costa_1445418000_1445904000_0002.json
# 	  3 / 4
# 	 Name of file on disk: data_Contra Costa_1445418000_1445904000_0003.json
# 	  4 / 4
# 	 Name of file on disk: data_Contra Costa_1445418000_1445904000_0004.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 17453.0 ( 45 )
# 	 Final number of images in response (timestep): 2325.0 ( 5.625 )
# 	 Time window (min/max): 2015-10-15 18:00:00 2015-10-21 09:00:00
# 	 Max. page number: 5
# 	 First file on disk: data_Contra Costa_1444932000_1445418000_0001.json
# 	  1 / 5
# 	  2 / 5
# 	 Name of file on disk: data_Contra Costa_1444932000_1445418000_0002.json
# 	  3 / 5
# 	 Name of file on disk: data_Contra Costa_1444932000_1445418000_0003.json
# 	  4 / 5
# 	 Name of file on disk: data_Contra Costa_1444932000_1445418000_0004.json
# 	  5 / 5
# 	 Name of file on disk: data_Contra Costa_1444932000_1445418000_0005.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 16785.0 ( 45 )
# 	 Final number of images in response (timestep): 2975.0 ( 5.625 )
# 	 Time window (min/max): 2015-10-10 03:00:00 2015-10-15 18:00:00
# 	 Max. page number: 6
# 	 First file on disk: data_Contra Costa_1444446000_1444932000_0001.json
# 	  1 / 6
# 	  2 / 6
# 	 Name of file on disk: data_Contra Costa_1444446000_1444932000_0002.json
# 	  3 / 6
# 	 Name of file on disk: data_Contra Costa_1444446000_1444932000_0003.json
# 	  4 / 6
# 	 Name of file on disk: data_Contra Costa_1444446000_1444932000_0004.json
# 	  5 / 6
# 	 Name of file on disk: data_Contra Costa_1444446000_1444932000_0005.json
# 	  6 / 6
# 	 Name of file on disk: data_Contra Costa_1444446000_1444932000_0006.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 15740.0 ( 45 )
# 	 Final number of images in response (timestep): 3880.0 ( 11.25 )
# 	 Time window (min/max): 2015-09-28 21:00:00 2015-10-10 03:00:00
# 	 Max. page number: 8
# 	 First file on disk: data_Contra Costa_1443474000_1444446000_0001.json
# 	  1 / 8
# 	  2 / 8
# 	 Name of file on disk: data_Contra Costa_1443474000_1444446000_0002.json
# 	  3 / 8
# 	 Name of file on disk: data_Contra Costa_1443474000_1444446000_0003.json
# 	  4 / 8
# 	 Name of file on disk: data_Contra Costa_1443474000_1444446000_0004.json
# 	  5 / 8
# 	 Name of file on disk: data_Contra Costa_1443474000_1444446000_0005.json
# 	  6 / 8
# 	 Name of file on disk: data_Contra Costa_1443474000_1444446000_0006.json
# 	  7 / 8
# 	 Name of file on disk: data_Contra Costa_1443474000_1444446000_0007.json
# 	  8 / 8
# 	 Name of file on disk: data_Contra Costa_1443474000_1444446000_0008.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 16429.0 ( 45 )
# 	 Final number of images in response (timestep): 1269.0 ( 5.625 )
# 	 Time window (min/max): 2015-09-23 06:00:00 2015-09-28 21:00:00
# 	 Max. page number: 3
# 	 First file on disk: data_Contra Costa_1442988000_1443474000_0001.json
# 	  1 / 3
# 	  2 / 3
# 	 Name of file on disk: data_Contra Costa_1442988000_1443474000_0002.json
# 	  3 / 3
# 	 Name of file on disk: data_Contra Costa_1442988000_1443474000_0003.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 18106.0 ( 45 )
# 	 Final number of images in response (timestep): 2793.0 ( 5.625 )
# 	 Time window (min/max): 2015-09-17 15:00:00 2015-09-23 06:00:00
# 	 Max. page number: 6
# 	 First file on disk: data_Contra Costa_1442502000_1442988000_0001.json
# 	  1 / 6
# 	  2 / 6
# 	 Name of file on disk: data_Contra Costa_1442502000_1442988000_0002.json
# 	  3 / 6
# 	 Name of file on disk: data_Contra Costa_1442502000_1442988000_0003.json
# 	  4 / 6
# 	 Name of file on disk: data_Contra Costa_1442502000_1442988000_0004.json
# 	  5 / 6
# 	 Name of file on disk: data_Contra Costa_1442502000_1442988000_0005.json
# 	  6 / 6
# 	 Name of file on disk: data_Contra Costa_1442502000_1442988000_0006.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 17548.0 ( 45 )
# 	 Final number of images in response (timestep): 1935.0 ( 5.625 )
# 	 Time window (min/max): 2015-09-12 00:00:00 2015-09-17 15:00:00
# 	 Max. page number: 4
# 	 First file on disk: data_Contra Costa_1442016000_1442502000_0001.json
# 	  1 / 4
# 	  2 / 4
# 	 Name of file on disk: data_Contra Costa_1442016000_1442502000_0002.json
# 	  3 / 4
# 	 Name of file on disk: data_Contra Costa_1442016000_1442502000_0003.json
# 	  4 / 4
# 	 Name of file on disk: data_Contra Costa_1442016000_1442502000_0004.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 17374.0 ( 45 )
# 	 Final number of images in response (timestep): 3952.0 ( 11.25 )
# 	 Time window (min/max): 2015-08-31 18:00:00 2015-09-12 00:00:00
# 	 Max. page number: 8
# 	 First file on disk: data_Contra Costa_1441044000_1442016000_0001.json
# 	  1 / 8
# 	  2 / 8
# 	 Name of file on disk: data_Contra Costa_1441044000_1442016000_0002.json
# 	  3 / 8
# 	 Name of file on disk: data_Contra Costa_1441044000_1442016000_0003.json
# 	  4 / 8
# 	 Name of file on disk: data_Contra Costa_1441044000_1442016000_0004.json
# 	  5 / 8
# 	 Name of file on disk: data_Contra Costa_1441044000_1442016000_0005.json
# 	  6 / 8
# 	 Name of file on disk: data_Contra Costa_1441044000_1442016000_0006.json
# 	  7 / 8
# 	 Name of file on disk: data_Contra Costa_1441044000_1442016000_0007.json
# 	  8 / 8
# 	 Name of file on disk: data_Contra Costa_1441044000_1442016000_0008.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 20741.0 ( 45 )
# 	 Final number of images in response (timestep): 3891.0 ( 11.25 )
# 	 Time window (min/max): 2015-08-20 12:00:00 2015-08-31 18:00:00
# 	 Max. page number: 8
# 	 First file on disk: data_Contra Costa_1440072000_1441044000_0001.json
# 	  1 / 8
# 	  2 / 8
# 	 Name of file on disk: data_Contra Costa_1440072000_1441044000_0002.json
# 	  3 / 8
# 	 Name of file on disk: data_Contra Costa_1440072000_1441044000_0003.json
# 	  4 / 8
# 	 Name of file on disk: data_Contra Costa_1440072000_1441044000_0004.json
# 	  5 / 8
# 	 Name of file on disk: data_Contra Costa_1440072000_1441044000_0005.json
# 	  6 / 8
# 	 Name of file on disk: data_Contra Costa_1440072000_1441044000_0006.json
# 	  7 / 8
# 	 Name of file on disk: data_Contra Costa_1440072000_1441044000_0007.json
# 	  8 / 8
# 	 Name of file on disk: data_Contra Costa_1440072000_1441044000_0008.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 21659.0 ( 45 )
# 	 Final number of images in response (timestep): 2599.0 ( 5.625 )
# 	 Time window (min/max): 2015-08-14 21:00:00 2015-08-20 12:00:00
# 	 Max. page number: 6
# 	 First file on disk: data_Contra Costa_1439586000_1440072000_0001.json
# 	  1 / 6
# 	  2 / 6
# 	 Name of file on disk: data_Contra Costa_1439586000_1440072000_0002.json
# 	  3 / 6
# 	 Name of file on disk: data_Contra Costa_1439586000_1440072000_0003.json
# 	  4 / 6
# 	 Name of file on disk: data_Contra Costa_1439586000_1440072000_0004.json
# 	  5 / 6
# 	 Name of file on disk: data_Contra Costa_1439586000_1440072000_0005.json
# 	  6 / 6
# 	 Name of file on disk: data_Contra Costa_1439586000_1440072000_0006.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 22489.0 ( 45 )
# 	 Final number of images in response (timestep): 2946.0 ( 5.625 )
# 	 Time window (min/max): 2015-08-09 06:00:00 2015-08-14 21:00:00
# 	 Max. page number: 6
# 	 First file on disk: data_Contra Costa_1439100000_1439586000_0001.json
# 	  1 / 6
# 	  2 / 6
# 	 Name of file on disk: data_Contra Costa_1439100000_1439586000_0002.json
# 	  3 / 6
# 	 Name of file on disk: data_Contra Costa_1439100000_1439586000_0003.json
# 	  4 / 6
# 	 Name of file on disk: data_Contra Costa_1439100000_1439586000_0004.json
# 	  5 / 6
# 	 Name of file on disk: data_Contra Costa_1439100000_1439586000_0005.json
# 	  6 / 6
# 	 Name of file on disk: data_Contra Costa_1439100000_1439586000_0006.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 23013.0 ( 45 )
# 	 Final number of images in response (timestep): 2230.0 ( 5.625 )
# 	 Time window (min/max): 2015-08-03 15:00:00 2015-08-09 06:00:00
# 	 Max. page number: 5
# 	 First file on disk: data_Contra Costa_1438614000_1439100000_0001.json
# 	  1 / 5
# 	  2 / 5
# 	 Name of file on disk: data_Contra Costa_1438614000_1439100000_0002.json
# 	  3 / 5
# 	 Name of file on disk: data_Contra Costa_1438614000_1439100000_0003.json
# 	  4 / 5
# 	 Name of file on disk: data_Contra Costa_1438614000_1439100000_0004.json
# 	  5 / 5
# 	 Name of file on disk: data_Contra Costa_1438614000_1439100000_0005.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 22626.0 ( 45 )
# 	 Final number of images in response (timestep): 1797.0 ( 5.625 )
# 	 Time window (min/max): 2015-07-29 00:00:00 2015-08-03 15:00:00
# 	 Max. page number: 4
# 	 First file on disk: data_Contra Costa_1438128000_1438614000_0001.json
# 	  1 / 4
# 	  2 / 4
# 	 Name of file on disk: data_Contra Costa_1438128000_1438614000_0002.json
# 	  3 / 4
# 	 Name of file on disk: data_Contra Costa_1438128000_1438614000_0003.json
# 	  4 / 4
# 	 Name of file on disk: data_Contra Costa_1438128000_1438614000_0004.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 22893.0 ( 45 )
# 	 Final number of images in response (timestep): 3808.0 ( 2.8125 )
# 	 Time window (min/max): 2015-07-26 04:30:00 2015-07-29 00:00:00
# 	 Max. page number: 8
# 	 First file on disk: data_Contra Costa_1437885000_1438128000_0001.json
# 	  1 / 8
# 	  2 / 8
# 	 Name of file on disk: data_Contra Costa_1437885000_1438128000_0002.json
# 	  3 / 8
# 	 Name of file on disk: data_Contra Costa_1437885000_1438128000_0003.json
# 	  4 / 8
# 	 Name of file on disk: data_Contra Costa_1437885000_1438128000_0004.json
# 	  5 / 8
# 	 Name of file on disk: data_Contra Costa_1437885000_1438128000_0005.json
# 	  6 / 8
# 	 Name of file on disk: data_Contra Costa_1437885000_1438128000_0006.json
# 	  7 / 8
# 	 Name of file on disk: data_Contra Costa_1437885000_1438128000_0007.json
# 	  8 / 8
# 	 Name of file on disk: data_Contra Costa_1437885000_1438128000_0008.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 20314.0 ( 45 )
# 	 Final number of images in response (timestep): 2052.0 ( 5.625 )
# 	 Time window (min/max): 2015-07-20 13:30:00 2015-07-26 04:30:00
# 	 Max. page number: 5
# 	 First file on disk: data_Contra Costa_1437399000_1437885000_0001.json
# 	  1 / 5
# 	  2 / 5
# 	 Name of file on disk: data_Contra Costa_1437399000_1437885000_0002.json
# 	  3 / 5
# 	 Name of file on disk: data_Contra Costa_1437399000_1437885000_0003.json
# 	  4 / 5
# 	 Name of file on disk: data_Contra Costa_1437399000_1437885000_0004.json
# 	  5 / 5
# 	 Name of file on disk: data_Contra Costa_1437399000_1437885000_0005.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 20555.0 ( 45 )
# 	 Final number of images in response (timestep): 2293.0 ( 5.625 )
# 	 Time window (min/max): 2015-07-14 22:30:00 2015-07-20 13:30:00
# 	 Max. page number: 5
# 	 First file on disk: data_Contra Costa_1436913000_1437399000_0001.json
# 	  1 / 5
# 	  2 / 5
# 	 Name of file on disk: data_Contra Costa_1436913000_1437399000_0002.json
# 	  3 / 5
# 	 Name of file on disk: data_Contra Costa_1436913000_1437399000_0003.json
# 	  4 / 5
# 	 Name of file on disk: data_Contra Costa_1436913000_1437399000_0004.json
# 	  5 / 5
# 	 Name of file on disk: data_Contra Costa_1436913000_1437399000_0005.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 21236.0 ( 45 )
# 	 Final number of images in response (timestep): 2399.0 ( 5.625 )
# 	 Time window (min/max): 2015-07-09 07:30:00 2015-07-14 22:30:00
# 	 Max. page number: 5
# 	 First file on disk: data_Contra Costa_1436427000_1436913000_0001.json
# 	  1 / 5
# 	  2 / 5
# 	 Name of file on disk: data_Contra Costa_1436427000_1436913000_0002.json
# 	  3 / 5
# 	 Name of file on disk: data_Contra Costa_1436427000_1436913000_0003.json
# 	  4 / 5
# 	 Name of file on disk: data_Contra Costa_1436427000_1436913000_0004.json
# 	  5 / 5
# 	 Name of file on disk: data_Contra Costa_1436427000_1436913000_0005.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 21723.0 ( 45 )
# 	 Final number of images in response (timestep): 3113.0 ( 5.625 )
# 	 Time window (min/max): 2015-07-03 16:30:00 2015-07-09 07:30:00
# 	 Max. page number: 7
# 	 First file on disk: data_Contra Costa_1435941000_1436427000_0001.json
# 	  1 / 7
# 	  2 / 7
# 	 Name of file on disk: data_Contra Costa_1435941000_1436427000_0002.json
# 	  3 / 7
# 	 Name of file on disk: data_Contra Costa_1435941000_1436427000_0003.json
# 	  4 / 7
# 	 Name of file on disk: data_Contra Costa_1435941000_1436427000_0004.json
# 	  5 / 7
# 	 Name of file on disk: data_Contra Costa_1435941000_1436427000_0005.json
# 	  6 / 7
# 	 Name of file on disk: data_Contra Costa_1435941000_1436427000_0006.json
# 	  7 / 7
# 	 Name of file on disk: data_Contra Costa_1435941000_1436427000_0007.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 20940.0 ( 45 )
# 	 Final number of images in response (timestep): 3606.0 ( 5.625 )
# 	 Time window (min/max): 2015-06-28 01:30:00 2015-07-03 16:30:00
# 	 Max. page number: 8
# 	 First file on disk: data_Contra Costa_1435455000_1435941000_0001.json
# 	  1 / 8
# 	  2 / 8
# 	 Name of file on disk: data_Contra Costa_1435455000_1435941000_0002.json
# 	  3 / 8
# 	 Name of file on disk: data_Contra Costa_1435455000_1435941000_0003.json
# 	  4 / 8
# 	 Name of file on disk: data_Contra Costa_1435455000_1435941000_0004.json
# 	  5 / 8
# 	 Name of file on disk: data_Contra Costa_1435455000_1435941000_0005.json
# 	  6 / 8
# 	 Name of file on disk: data_Contra Costa_1435455000_1435941000_0006.json
# 	  7 / 8
# 	 Name of file on disk: data_Contra Costa_1435455000_1435941000_0007.json
# 	  8 / 8
# 	 Name of file on disk: data_Contra Costa_1435455000_1435941000_0008.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 20464.0 ( 45 )
# 	 Final number of images in response (timestep): 2392.0 ( 5.625 )
# 	 Time window (min/max): 2015-06-22 10:30:00 2015-06-28 01:30:00
# 	 Max. page number: 5
# 	 First file on disk: data_Contra Costa_1434969000_1435455000_0001.json
# 	  1 / 5
# 	  2 / 5
# 	 Name of file on disk: data_Contra Costa_1434969000_1435455000_0002.json
# 	  3 / 5
# 	 Name of file on disk: data_Contra Costa_1434969000_1435455000_0003.json
# 	  4 / 5
# 	 Name of file on disk: data_Contra Costa_1434969000_1435455000_0004.json
# 	  5 / 5
# 	 Name of file on disk: data_Contra Costa_1434969000_1435455000_0005.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 22154.0 ( 45 )
# 	 Final number of images in response (timestep): 2137.0 ( 5.625 )
# 	 Time window (min/max): 2015-06-16 19:30:00 2015-06-22 10:30:00
# 	 Max. page number: 5
# 	 First file on disk: data_Contra Costa_1434483000_1434969000_0001.json
# 	  1 / 5
# 	  2 / 5
# 	 Name of file on disk: data_Contra Costa_1434483000_1434969000_0002.json
# 	  3 / 5
# 	 Name of file on disk: data_Contra Costa_1434483000_1434969000_0003.json
# 	  4 / 5
# 	 Name of file on disk: data_Contra Costa_1434483000_1434969000_0004.json
# 	  5 / 5
# 	 Name of file on disk: data_Contra Costa_1434483000_1434969000_0005.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 22318.0 ( 45 )
# 	 Final number of images in response (timestep): 2388.0 ( 5.625 )
# 	 Time window (min/max): 2015-06-11 04:30:00 2015-06-16 19:30:00
# 	 Max. page number: 5
# 	 First file on disk: data_Contra Costa_1433997000_1434483000_0001.json
# 	  1 / 5
# 	  2 / 5
# 	 Name of file on disk: data_Contra Costa_1433997000_1434483000_0002.json
# 	  3 / 5
# 	 Name of file on disk: data_Contra Costa_1433997000_1434483000_0003.json
# 	  4 / 5
# 	 Name of file on disk: data_Contra Costa_1433997000_1434483000_0004.json
# 	  5 / 5
# 	 Name of file on disk: data_Contra Costa_1433997000_1434483000_0005.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 22783.0 ( 45 )
# 	 Final number of images in response (timestep): 2259.0 ( 5.625 )
# 	 Time window (min/max): 2015-06-05 13:30:00 2015-06-11 04:30:00
# 	 Max. page number: 5
# 	 First file on disk: data_Contra Costa_1433511000_1433997000_0001.json
# 	  1 / 5
# 	  2 / 5
# 	 Name of file on disk: data_Contra Costa_1433511000_1433997000_0002.json
# 	  3 / 5
# 	 Name of file on disk: data_Contra Costa_1433511000_1433997000_0003.json
# 	  4 / 5
# 	 Name of file on disk: data_Contra Costa_1433511000_1433997000_0004.json
# 	  5 / 5
# 	 Name of file on disk: data_Contra Costa_1433511000_1433997000_0005.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 23517.0 ( 45 )
# 	 Final number of images in response (timestep): 2970.0 ( 5.625 )
# 	 Time window (min/max): 2015-05-30 22:30:00 2015-06-05 13:30:00
# 	 Max. page number: 6
# 	 First file on disk: data_Contra Costa_1433025000_1433511000_0001.json
# 	  1 / 6
# 	  2 / 6
# 	 Name of file on disk: data_Contra Costa_1433025000_1433511000_0002.json
# 	  3 / 6
# 	 Name of file on disk: data_Contra Costa_1433025000_1433511000_0003.json
# 	  4 / 6
# 	 Name of file on disk: data_Contra Costa_1433025000_1433511000_0004.json
# 	  5 / 6
# 	 Name of file on disk: data_Contra Costa_1433025000_1433511000_0005.json
# 	  6 / 6
# 	 Name of file on disk: data_Contra Costa_1433025000_1433511000_0006.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 22236.0 ( 45 )
# 	 Final number of images in response (timestep): 2752.0 ( 5.625 )
# 	 Time window (min/max): 2015-05-25 07:30:00 2015-05-30 22:30:00
# 	 Max. page number: 6
# 	 First file on disk: data_Contra Costa_1432539000_1433025000_0001.json
# 	  1 / 6
# 	  2 / 6
# 	 Name of file on disk: data_Contra Costa_1432539000_1433025000_0002.json
# 	  3 / 6
# 	 Name of file on disk: data_Contra Costa_1432539000_1433025000_0003.json
# 	  4 / 6
# 	 Name of file on disk: data_Contra Costa_1432539000_1433025000_0004.json
# 	  5 / 6
# 	 Name of file on disk: data_Contra Costa_1432539000_1433025000_0005.json
# 	  6 / 6
# 	 Name of file on disk: data_Contra Costa_1432539000_1433025000_0006.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 23517.0 ( 45 )
# 	 Final number of images in response (timestep): 2264.0 ( 5.625 )
# ...
# 	 Time window (min/max): 1977-04-21 13:52:30 1977-06-05 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_230478750_234366750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1977-03-07 13:52:30 1977-04-21 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_226590750_230478750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1977-01-21 13:52:30 1977-03-07 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_222702750_226590750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1976-12-07 13:52:30 1977-01-21 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_218814750_222702750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1976-10-23 13:52:30 1976-12-07 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_214926750_218814750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1976-09-08 13:52:30 1976-10-23 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_211038750_214926750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1976-07-25 13:52:30 1976-09-08 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_207150750_211038750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1976-06-10 13:52:30 1976-07-25 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_203262750_207150750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1976-04-26 13:52:30 1976-06-10 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_199374750_203262750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1976-03-12 13:52:30 1976-04-26 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_195486750_199374750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1976-01-27 13:52:30 1976-03-12 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_191598750_195486750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1975-12-13 13:52:30 1976-01-27 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_187710750_191598750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1975-10-29 13:52:30 1975-12-13 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_183822750_187710750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1975-09-14 13:52:30 1975-10-29 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_179934750_183822750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1975-07-31 13:52:30 1975-09-14 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_176046750_179934750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1975-06-16 13:52:30 1975-07-31 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_172158750_176046750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1975-05-02 13:52:30 1975-06-16 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_168270750_172158750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1975-03-18 13:52:30 1975-05-02 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_164382750_168270750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1975-02-01 13:52:30 1975-03-18 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_160494750_164382750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1974-12-18 13:52:30 1975-02-01 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_156606750_160494750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1974-11-03 13:52:30 1974-12-18 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_152718750_156606750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1974-09-19 13:52:30 1974-11-03 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_148830750_152718750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1974-08-05 13:52:30 1974-09-19 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_144942750_148830750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1974-06-21 13:52:30 1974-08-05 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_141054750_144942750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1974-05-07 13:52:30 1974-06-21 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_137166750_141054750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1974-03-23 13:52:30 1974-05-07 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_133278750_137166750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1974-02-06 13:52:30 1974-03-23 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_129390750_133278750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1973-12-23 13:52:30 1974-02-06 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_125502750_129390750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1973-11-08 13:52:30 1973-12-23 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_121614750_125502750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1973-09-24 13:52:30 1973-11-08 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_117726750_121614750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1973-08-10 13:52:30 1973-09-24 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_113838750_117726750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1973-06-26 13:52:30 1973-08-10 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_109950750_113838750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1973-05-12 13:52:30 1973-06-26 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_106062750_109950750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1973-03-28 13:52:30 1973-05-12 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_102174750_106062750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1973-02-11 13:52:30 1973-03-28 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_98286750_102174750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1972-12-28 13:52:30 1973-02-11 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_94398750_98286750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1972-11-13 13:52:30 1972-12-28 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_90510750_94398750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1972-09-29 13:52:30 1972-11-13 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_86622750_90510750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1972-08-15 13:52:30 1972-09-29 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_82734750_86622750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1972-07-01 13:52:30 1972-08-15 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_78846750_82734750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1972-05-17 13:52:30 1972-07-01 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_74958750_78846750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1972-04-02 13:52:30 1972-05-17 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_71070750_74958750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1972-02-17 13:52:30 1972-04-02 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_67182750_71070750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1972-01-03 13:52:30 1972-02-17 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_63294750_67182750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1971-11-19 13:52:30 1972-01-03 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_59406750_63294750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1971-10-05 13:52:30 1971-11-19 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_55518750_59406750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1971-08-21 13:52:30 1971-10-05 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_51630750_55518750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1971-07-07 13:52:30 1971-08-21 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_47742750_51630750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1971-05-23 13:52:30 1971-07-07 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_43854750_47742750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1971-04-08 13:52:30 1971-05-23 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_39966750_43854750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1971-02-22 13:52:30 1971-04-08 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_36078750_39966750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1971-01-08 13:52:30 1971-02-22 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_32190750_36078750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1970-11-24 13:52:30 1971-01-08 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_28302750_32190750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1970-10-10 13:52:30 1970-11-24 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_24414750_28302750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1970-08-26 13:52:30 1970-10-10 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_20526750_24414750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1970-07-12 13:52:30 1970-08-26 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_16638750_20526750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1970-05-28 13:52:30 1970-07-12 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_12750750_16638750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1970-04-13 13:52:30 1970-05-28 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_8862750_12750750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1970-02-27 13:52:30 1970-04-13 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_4974750_8862750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1970-01-13 13:52:30 1970-02-27 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_1086750_4974750_0001.json
# 	 ------------------------------------------
# 	 Initial number of images in response (timestep): 0.0 ( 45 )
# 	 Time window (min/max): 1969-11-29 13:52:30 1970-01-13 13:52:30
# 	 Max. page number: 0
# 	 First file on disk: data_Contra Costa_-2801250_1086750_0001.json
# 	 ------------------------------------------

# %%
# Get a list of all 'photo_id's
image_id_all = []
for county in counties:
    tmp_dir = os.path.join('..','data','photo_search',county)
    base_dir = os.path.join('..','data','photo_details')
    dest_dir = os.path.join(base_dir,county)
    checkdir(dest_dir)
    json_list = glob.glob(os.path.join(tmp_dir,'*json'))
    for tmp_json in json_list:
        # open json file
        with open(tmp_json, 'r') as f:
            data = json.load(f)
        # get image list
        image_list = data['photos']['photo']
        # get all 'image_id's in list
        for image in image_list:
            image_id_all.append((image['id'],county))
